# %% [markdown]
# ## Condicionais
# Estruturas que permitem escolher algo

# %%
# if
cor = 'preto'
if (cor == 'preto'):
    print('você é cotista')
elif (cor == 'pardo'):
    print('você é cotista')
else: 
    print('você não é cotista')
